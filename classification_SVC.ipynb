# %%
import pandas as pd
df = pd.read_csv("/content/cleaned_76hd.csv")

# %%
df.shape
# Out:
# (282, 40)

# %%
df.drop('V1',axis=1,inplace=True)

# %%
df.isnull().sum()
# Out:
# V3     0
# V4     0
# V9     0
# V10    0
# V11    0
# V12    0
# V14    0
# V15    0
# V16    0
# V18    0
# V19    0
# V20    0
# V21    0
# V22    0
# V23    0
# V24    0
# V25    0
# V26    0
# V27    0
# V28    0
# V29    0
# V30    0
# V31    0
# V32    0
# V33    0
# V34    0
# V35    0
# V37    0
# V38    0
# V39    0
# V40    0
# V41    0
# V43    0
# V44    0
# V51    0
# V55    0
# V56    0
# V57    0
# V58    0
# dtype: int64

# %% [markdown]
# split in x & *y* v58 is target y

# %%
X=df.drop('V58',axis=1)
Y=df['V58']

# %%
X.shape,Y.shape
# Out:
# ((282, 38), (282,))

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,
                                                 test_size=0.3,random_state=7,
                                                 stratify=Y)

# %%
X_train.shape,X_test.shape,Y_train.shape,Y_test.shape
# Out:
# ((197, 38), (85, 38), (197,), (85,))

# %%
from sklearn.naive_bayes import BernoulliNB, GaussianNB,MultinomialNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression

# %%
svc = SVC(class_weight="balanced", random_state=7)

# %%
svc.fit(X_train,Y_train)
# Out:
# SVC(class_weight='balanced', random_state=7)

# %%
svc.dual_coef_
# Out:
# array([[-0.80589072, -0.91203704, -0.58071377, -0.91203704, -0.91203704,
#         -0.91203704, -0.91203704, -0.91203704, -0.91203704, -0.91203704,
#         -0.91203704, -0.91203704, -0.91203704, -0.91203704, -0.55795691,
#         -0.11634116, -0.0238975 , -0.91203704, -0.91203704, -0.35146862,
#         -0.91203704, -0.91203704, -0.51209435, -0.91203704, -0.2689481 ,
#         -0.87308601, -0.91203704, -0.91203704, -0.91203704, -0.91203704,
#         -0.91203704, -0.91203704, -0.91203704, -0.91203704, -0.17918951,
#         -0.28458532, -0.72929261, -0.12751808, -0.22245638, -0.48818813,
#         -0.91203704, -0.7682463 , -0.91203704, -0.50954767, -0.91203704,
#         -0.91203704, -0.91203704, -0.91203704, -0.91203704, -0.42888593,
#         -0.91203704, -0.46017468, -0.91203704, -0.91203704, -0.91203704,
#         -0.91203704, -0.75454826, -0.91203704, -0.69092394, -0.02067802,
#         -0.91203704, -0.91203704, -0.2017884 , -0.65258124, -0.91203704,
#          0.95263454,  0.72008518,  1.10674157,  0.99254581,  1.10674157,
#          0.35558932,  0.26933144,  1.10674157,  1.10674157,  0.33139592,
#          1.10674157,  1.10674157,  1.10674157,  1.10674157,  0.2902511 ,
#          1.10674157,  0.00789119,  1.10674157,  0.82765833,  1.10674157,
#          1.10674157,  1.10674157,  1.10674157,  0.56628757,  0.23868367,
#          1.10674157,  1.10674157,  1.10674157,  0.99431438,  1.10674157,
#          0.64848987,  1.10674157,  1.10674157,  1.10674157,  0.83118277,
#          0.0812174 ,  0.87057278,  1.10674157,  1.10674157,  0.48033514,
#          1.10674157,  1.10674157,  0.93770942,  1.10674157,  0.32624806,
#          1.10674157,  0.40421097,  1.10674157,  1.10674157,  1.10674157,
#          1.10674157,  0.35341335,  1.10674157,  1.10674157]])

# %%
Y_pred = lr.predict(X_test)

# %%
Y_test.shape, Y_pred.shape
# Out:
# ((85,), (85,))

# %%
from sklearn.metrics import classification_report
print(classification_report(Y_test,Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.82      0.78      0.80        46
#          1.0       0.76      0.79      0.77        39
#
#     accuracy                           0.79        85
#    macro avg       0.79      0.79      0.79        85
# weighted avg       0.79      0.79      0.79        85
